# %%
import random

# GENERATE RANDOM
nilaiTugas = []
for i in range(250):
    nilaiTugas.append(random.randrange(1,100,1))

print(nilaiTugas)

# TAMPILKAN:
# ganjil
for n in nilaiTugas:
    if n%2==1:
        print(n)
    
# nilai > 70
print("------------nilai > 70------------------")
count=0
for n in nilaiTugas:
    if n>70:
        count=count+1
print(count)
        
# standar deviasi
print("---------------standar deviasi---------------")
total1=0
for n in nilaiTugas:
    total1=total1+n

rata=total1/len(nilaiTugas)

total2=0
for n in nilaiTugas:
    total2=total2+(n-rata)**2

standardeviasi=(total2/len(nilaiTugas))**(0.5)

print("standar deviasinya:", standardeviasi)
    
# maksimum
print("---------------Maksimum---------------")
for n in nilaiTugas:
    for m in nilaiTugas:
        if m>n:
            n=m
print ("nilai maksimum:", n)
        
# minimum
print("---------------Minimum---------------")
for n in nilaiTugas:
    for m in nilaiTugas:
        if m<n:
            n=m
print ("nilai minimum:", n)

# modus1
print("---------------Modus---------------")
i=0
j=0
k=0
m=0
nilai=[0]
count=[0]
while i<=249:
    while j<=249:
        if nilaiTugas[i]==nilaiTugas[j]:
            count[k]=count[k]+1
        j=j+1
    count.append(0)
    if k>1:
        if count[k]>=modus:
            modus=count[k]
            m=i
    else:
        modus=count[0]
    i=i+1
    k=k+1
    j=k

i=0
l=0

#Sintaks apabila multimodus
while i<=249:
    if count[i]==modus:
        nilai[l]=nilaiTugas[i]
        nilai.append(0)
        l=l+1
    i=i+1


i=0
print("Modusnya adalah: ")
if nilai[i]!=0:
    while i<l:
        print(nilai[i])
        i=i+1
        
print("sebanyak", modus)

#moduscara2
print("---------------\nPAKAI CARA LAIN")
newNilai={}
count1=[]
bodo=[]
unique=list(set(nilaiTugas))
count=0
for m in unique:
    for n in nilaiTugas:
        if n==m:
            count=count+1
    count1.append(count)
    newNilai[m]=count
    count=0

for p in count1:
    for q in count1:
        if q>p:
            p=q
            
print("Modus:")
for k,v in newNilai.items():
    if v==p:
        print(k)

        
print("sebanyak", p)
# Out:
# [95, 18, 41, 82, 81, 77, 47, 73, 59, 97, 16, 69, 12, 37, 6, 23, 91, 19, 23, 52, 47, 98, 87, 9, 51, 84, 44, 9, 50, 15, 81, 25, 27, 67, 58, 18, 31, 77, 38, 80, 3, 31, 4, 22, 28, 26, 43, 20, 49, 89, 96, 85, 15, 22, 60, 68, 69, 72, 38, 38, 47, 39, 80, 17, 19, 98, 17, 33, 18, 60, 71, 72, 19, 29, 40, 79, 14, 14, 21, 29, 46, 84, 17, 47, 68, 51, 64, 14, 37, 68, 72, 8, 94, 27, 1, 33, 67, 38, 29, 9, 14, 57, 78, 75, 28, 8, 90, 58, 26, 9, 99, 43, 5, 28, 45, 25, 59, 70, 66, 12, 43, 46, 37, 70, 12, 61, 53, 24, 39, 69, 18, 41, 90, 13, 44, 7, 29, 52, 39, 98, 56, 21, 65, 27, 20, 24, 60, 18, 94, 10, 29, 20, 84, 31, 93, 57, 28, 91, 21, 70, 56, 84, 45, 60, 1, 51, 74, 64, 86, 50, 68, 68, 88, 1, 69, 74, 30, 79, 41, 12, 37, 86, 64, 56, 24, 1, 7, 84, 12, 31, 14, 17, 50, 26, 35, 46, 37, 54, 76, 98, 86, 58, 8, 55, 78, 29, 50, 26, 24, 1, 80, 9, 92, 55, 23, 16, 90, 43, 76, 77, 59, 20, 73, 72, 37, 50, 78, 42, 52, 16, 50, 37, 81, 46, 12, 65, 95, 75, 25, 93, 18, 20, 9, 60, 56, 32, 64, 62, 16, 75]
# 95
# 41
# 81
# ...
