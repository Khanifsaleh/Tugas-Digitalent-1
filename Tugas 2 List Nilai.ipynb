# %%
import random

# GENERATE RANDOM
nilaiTugas = []
for i in range(250):
    nilaiTugas.append(random.randrange(1,100,1))

print(nilaiTugas)

# TAMPILKAN:
# ganjil
for n in nilaiTugas:
    if n%2==1:
        print(n)
    
# nilai > 70
count=0
for n in nilaiTugas:
    if n>70:
        count=count+1
print(count)
        
# standar deviasi
total1=0
for n in nilaiTugas:
    total1=total1+n

rata=total1/len(nilaiTugas)

total2=0
for n in nilaiTugas:
    total2=total2+(n-rata)**2

standardeviasi=(total2/len(nilaiTugas))**(0.5)

print("standar deviasinya:", standardeviasi)
    
# maksimum
for n in nilaiTugas:
    for m in nilaiTugas:
        if m>n:
            n=m
print ("nilai maksimum:", n)
        
# minimum
for n in nilaiTugas:
    for m in nilaiTugas:
        if m<n:
            n=m
print ("nilai minimum:", n)
# modus1
i=0
j=0
k=0
m=0
nilai=[0]
count=[0]
while i<=249:
    while j<=249:
        if nilaiTugas[i]==nilaiTugas[j]:
            count[k]=count[k]+1
        j=j+1
    count.append(0)
    if k>1:
        if count[k]>=modus:
            modus=count[k]
            m=i
    else:
        modus=count[0]
    i=i+1
    k=k+1
    j=k

i=0
l=0


while i<=249:
    if count[i]==modus:
        nilai[l]=nilaiTugas[i]
        nilai.append(0)
        l=l+1
    i=i+1


i=0
print("Modusnya adalah: ")
if nilai[i]!=0:
    while i<l:
        print(nilai[i])
        i=i+1
        
print("sebanyak", modus)

#modus2
# Out:
# [41, 5, 20, 40, 86, 9, 66, 92, 87, 43, 49, 75, 40, 11, 7, 89, 66, 61, 1, 53, 62, 87, 72, 26, 37, 78, 68, 28, 11, 76, 98, 23, 75, 25, 96, 87, 75, 49, 23, 42, 54, 2, 3, 76, 43, 67, 84, 90, 67, 12, 62, 7, 27, 16, 19, 26, 21, 33, 90, 8, 23, 43, 71, 11, 60, 44, 45, 81, 21, 48, 69, 61, 2, 10, 6, 39, 4, 37, 47, 49, 25, 62, 54, 15, 89, 94, 71, 11, 88, 39, 43, 84, 68, 32, 31, 77, 91, 18, 74, 78, 85, 77, 41, 48, 91, 19, 40, 1, 37, 1, 54, 73, 67, 84, 40, 61, 70, 70, 4, 92, 41, 22, 37, 89, 87, 14, 10, 57, 59, 4, 44, 90, 59, 83, 11, 77, 13, 91, 88, 94, 30, 48, 99, 39, 98, 19, 86, 44, 18, 44, 28, 44, 89, 26, 43, 84, 78, 50, 51, 23, 20, 61, 13, 54, 83, 96, 97, 2, 73, 10, 22, 46, 10, 58, 43, 56, 3, 75, 36, 71, 44, 30, 32, 11, 2, 59, 16, 57, 67, 73, 20, 9, 98, 56, 20, 51, 89, 33, 17, 56, 60, 81, 85, 32, 67, 63, 40, 85, 13, 29, 25, 34, 99, 12, 26, 84, 63, 71, 9, 40, 29, 56, 16, 40, 53, 18, 95, 12, 55, 23, 3, 57, 47, 92, 27, 78, 9, 22, 84, 44, 12, 40, 69, 59, 75, 41, 14, 65, 3, 11]
# 41
# 5
# 9
# 87
# 43
# 49
# 75
# 11
# 7
# 89
# 61
# 1
# 53
# 87
# 37
# 11
# 23
# 75
# 25
# 87
# 75
# 49
# 23
# 3
# 43
# 67
# 67
# 7
# 27
# 19
# 21
# 33
# 23
# 43
# 71
# 11
# 45
# 81
# 21
# 69
# 61
# 39
# 37
# 47
# 49
# 25
# 15
# 89
# 71
# 11
# 39
# 43
# 31
# 77
# 91
# 85
# 77
# 41
# 91
# 19
# 1
# 37
# 1
# 73
# 67
# 61
# 41
# 37
# 89
# 87
# 57
# 59
# 59
# 83
# 11
# 77
# 13
# 91
# 99
# 39
# 19
# 89
# 43
# 51
# 23
# 61
# 13
# 83
# 97
# 73
# 43
# 3
# 75
# 71
# 11
# 59
# 57
# 67
# 73
# 9
# 51
# 89
# 33
# 17
# 81
# 85
# 67
# 63
# 85
# 13
# 29
# 25
# 99
# 63
# 71
# 9
# 29
# 53
# 95
# 55
# 23
# 3
# 57
# 47
# 27
# 9
# 69
# 59
# 75
# 41
# 65
# 3
# 11
# 69
# standar deviasinya: 28.681768704178623
# nilai maksimum: 99
# nilai minimum: 1
# Modusnya adalah:
# 40
# sebanyak 8
